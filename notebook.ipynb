# %% [markdown]
# ## The Sketching Notebook, for current work ideas

# %%
from scripts.training_script import train_model

lstm_history = train_model(
    dataset_base="data_original",
    max_epochs=100,
    context_length=12,
    quantiles=(0.1, 0.5, 0.9),
)

# tensorboard --logdir ./results/logs
# Out:
# Epoch 1/100 - train_loss=4.750773 - train_rmse=15.862489 - val_loss=5.915404 - val_rmse=21.133117 - test_loss=5.503901 - test_rmse=19.642009
# Epoch 2/100 - train_loss=2.180799 - train_rmse=10.414728 - val_loss=3.623816 - val_rmse=15.005817 - test_loss=3.272442 - test_rmse=13.616539
# Epoch 3/100 - train_loss=1.418588 - train_rmse=7.752119 - val_loss=2.684912 - val_rmse=12.688829 - test_loss=2.500465 - test_rmse=11.337891
# Epoch 4/100 - train_loss=1.166929 - train_rmse=6.708945 - val_loss=2.162359 - val_rmse=11.402305 - test_loss=1.994461 - test_rmse=9.970340
# Epoch 5/100 - train_loss=1.022922 - train_rmse=6.010389 - val_loss=1.837897 - val_rmse=10.433820 - test_loss=1.745522 - test_rmse=8.913504
# Epoch 6/100 - train_loss=0.942861 - train_rmse=5.554337 - val_loss=1.675278 - val_rmse=9.744151 - test_loss=1.472054 - test_rmse=8.120226
# Epoch 7/100 - train_loss=0.888253 - train_rmse=5.231211 - val_loss=1.528158 - val_rmse=9.274072 - test_loss=1.368251 - test_rmse=7.637903
# Epoch 8/100 - train_loss=0.868206 - train_rmse=5.064420 - val_loss=1.435752 - val_rmse=8.998210 - test_loss=1.320480 - test_rmse=7.357761
# Epoch 9/100 - train_loss=0.840233 - train_rmse=4.890334 - val_loss=1.323003 - val_rmse=8.645754 - test_loss=1.222902 - test_rmse=6.948632
# Epoch 10/100 - train_loss=0.825109 - train_rmse=4.750157 - val_loss=1.330179 - val_rmse=8.487666 - test_loss=1.227048 - test_rmse=6.813100
# Epoch 11/100 - train_loss=0.809259 - train_rmse=4.643897 - val_loss=1.213974 - val_rmse=8.099911 - test_loss=1.185416 - test_rmse=6.456074
# Epoch 12/100 - train_loss=0.792914 - train_rmse=4.511014 - val_loss=1.163773 - val_rmse=7.879105 - test_loss=1.112761 - test_rmse=6.188680
# Epoch 13/100 - train_loss=0.788301 - train_rmse=4.463930 - val_loss=1.179609 - val_rmse=7.861524 - test_loss=1.141057 - test_rmse=6.116168
# Epoch 14/100 - train_loss=0.777211 - train_rmse=4.406591 - val_loss=1.131321 - val_rmse=7.663031 - test_loss=1.100713 - test_rmse=5.856343
# Epoch 15/100 - train_loss=0.765571 - train_rmse=4.295137 - val_loss=1.136240 - val_rmse=7.500063 - test_loss=1.043223 - test_rmse=5.572781
# Epoch 16/100 - train_loss=0.757912 - train_rmse=4.233688 - val_loss=1.114461 - val_rmse=7.352900 - test_loss=1.026671 - test_rmse=5.377275
# Epoch 17/100 - train_loss=0.748356 - train_rmse=4.151027 - val_loss=1.116287 - val_rmse=7.304617 - test_loss=1.067571 - test_rmse=5.306611
# Epoch 18/100 - train_loss=0.742137 - train_rmse=4.109975 - val_loss=1.103579 - val_rmse=7.195196 - test_loss=0.987870 - test_rmse=4.982452
# Epoch 19/100 - train_loss=0.737324 - train_rmse=4.062936 - val_loss=1.086414 - val_rmse=7.104716 - test_loss=0.953280 - test_rmse=5.005522
# Epoch 20/100 - train_loss=0.738666 - train_rmse=4.061475 - val_loss=1.098463 - val_rmse=6.986870 - test_loss=0.955803 - test_rmse=4.771646
# Epoch 21/100 - train_loss=0.731093 - train_rmse=4.013194 - val_loss=1.118014 - val_rmse=7.033504 - test_loss=0.947997 - test_rmse=4.733958
# Early stopping at epoch 22: train_rmse=3.959010, val_rmse=6.956539, test_rmse=4.641044
# 'Final metrics'
#                   metric     value
# 0             train_loss  0.724333
# 1             train_rmse  3.959010
# 2               val_loss  1.103651
# 3               val_rmse  6.956539
# 4             train_q0.1  0.488751
# 5             train_q0.5  1.071746
# 6             train_q0.9  0.612065
# 7               val_q0.1  0.733249
# 8               val_q0.5  1.707606
# 9               val_q0.9  1.114117
# 10        train_coverage  0.799742
# 11          val_coverage  0.767442
# 12  train_interval_width  6.385883
# 13    val_interval_width  9.050433
# 14             test_loss  0.905692
# 15             test_rmse  4.641044
# 16             test_q0.1  0.553165
# 17             test_q0.5  1.390482
# 18             test_q0.9  0.824062
# 19         test_coverage  0.825581
# 20   test_interval_width  8.485720
# 21              best_val  1.086414
# 22              patience       3/3

# %%
# Chronos-2 quantile evaluation on the input dataset
# Chronos2_eval.py automatically put device to cpu for evaluation
# !python3 scripts/chronos2_eval.py --data-path data/datasets/data_original_train.csv \
    --context-length 12 --quantiles 0.1,0.5,0.9
# Out:
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Chronos-2 metrics
#             metric     value
# 0             rmse  3.904853
# 1  median_quantile  0.500000
# 2         coverage  0.788114
# 3   interval_width  7.114337
# 4   interval_lower  0.100000
# 5   interval_upper  0.900000
# 6     pinball_q0.1  0.501699
# 7     pinball_q0.5  1.081675
# 8     pinball_q0.9  0.570550
# Saved results to results/evals/chronos2_test_rmse.json

# %%
# Chronos-2 quantile evaluation on the input dataset
# Chronos2_eval.py automatically put device to cpu for evaluation
# !python3 scripts/chronos2_eval.py --data-path data/datasets/data_original_val.csv \
    --context-length 12 --quantiles 0.1,0.5,0.9
# Out:
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Chronos-2 metrics
#             metric      value
# 0             rmse   3.296815
# 1  median_quantile   0.500000
# 2         coverage   0.883721
# 3   interval_width  11.812506
# 4   interval_lower   0.100000
# 5   interval_upper   0.900000
# 6     pinball_q0.1   0.582776
# 7     pinball_q0.5   1.173555
# 8     pinball_q0.9   0.701007
# Saved results to results/chronos_eval_benchmarking/evals/chronos2_eval.json

# %%
# Chronos-2 quantile evaluation on the input dataset
# Chronos2_eval.py automatically put device to cpu for evaluation
# !python3 scripts/chronos2_eval.py --data-path data/datasets/data_original_test.csv \
    --context-length 12 --quantiles 0.1,0.5,0.9
# Out:
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Chronos-2 metrics
#             metric     value
# 0             rmse  2.949635
# 1  median_quantile  0.500000
# 2         coverage  0.895349
# 3   interval_width  8.807986
# 4   interval_lower  0.100000
# 5   interval_upper  0.900000
# 6     pinball_q0.1  0.436435
# 7     pinball_q0.5  1.053503
# 8     pinball_q0.9  0.541610
# Saved results to results/chronos_eval_benchmarking/evals/chronos2_eval.json
