# %% [markdown]
# # Experiment Report
#
# Read-only view of saved experiment artifacts. Re-run `python src/regenerate_plots.py --window-seed N` to refresh plots without re-running heavy compute.

# %%
from __future__ import annotations

import ast, json, sys
from pathlib import Path

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
from IPython.display import Image, Markdown, display


# ── path helpers ──────────────────────────────────────────────────────────
def find_repo_root(start: Path) -> Path:
    for candidate in (start, *start.parents):
        if (candidate / "src").exists() and (candidate / "README.md").exists():
            return candidate
    return start

def default_experiment_dir(root: Path) -> Path:
    canonical = root / "results/experiments/data_tim_milan_10min_trainable_200_ctx144_h48/q50_q95_seed42"
    if canonical.exists():
        return canonical
    candidates = sorted((root / "results/experiments").glob("*/*"), key=lambda p: p.stat().st_mtime, reverse=True)
    return candidates[0] if candidates else canonical

ROOT = find_repo_root(Path.cwd().resolve())
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

_OVERRIDE = globals().get("EXPERIMENT_DIR_OVERRIDE", None)
EXPERIMENT_DIR = Path(_OVERRIDE) if _OVERRIDE else default_experiment_dir(ROOT)
if not EXPERIMENT_DIR.is_absolute():
    EXPERIMENT_DIR = (ROOT / EXPERIMENT_DIR).resolve()
REPORTS_DIR = EXPERIMENT_DIR / "reports"
CALIBRATED_PATH = EXPERIMENT_DIR / "calibrated_system_eval" / "calibrated_system_eval_comparison.csv"

print(f"Experiment : {EXPERIMENT_DIR}")
print(f"Reports    : {REPORTS_DIR}")


# ── display utils ─────────────────────────────────────────────────────────
def md(text):  display(Markdown(text))
def note(text): md(f"> {text}")

def read_json(path, quiet=False):
    if not path.exists():
        if not quiet: note(f"Missing: `{path.relative_to(ROOT)}`")
        return None
    return json.loads(path.read_text())

def read_csv(path, quiet=False):
    if not path.exists():
        if not quiet: note(f"Missing: `{path.relative_to(ROOT)}`")
        return None
    try:
        return pd.read_csv(path)
    except pd.errors.EmptyDataError:
        if not quiet: note(f"Empty: `{path.relative_to(ROOT)}`")
        return None

def show_png(path, title=None):
    if title: md(f"### {title}")
    if Path(path).exists():
        display(Image(filename=str(path)))
    else:
        note(f"PNG not found: `{Path(path).relative_to(ROOT)}`")

def show_table(path, title=None, rows=20):
    if title: md(f"### {title}")
    df = read_csv(path)
    if df is not None:
        display(df.head(rows))

def parse_seq(value):
    if isinstance(value, (list, np.ndarray)):
        return [float(v) for v in value]
    if pd.isna(value): return []
    if isinstance(value, str):
        for fn in (json.loads, ast.literal_eval):
            try:
                p = fn(value.strip())
                if isinstance(p, (list, tuple)): return [float(v) for v in p]
            except Exception: pass
    return []

def discover_metrics(summary_path, glob_suffix):
    rows = []
    payload = read_json(summary_path, quiet=True)
    if isinstance(payload, dict):
        for split, split_data in payload.get("splits", {}).items():
            for model, mdata in split_data.items():
                m = read_json(ROOT / mdata["metrics_path"], quiet=True)
                if isinstance(m, dict):
                    rows.append({"split": split, "model": model, **m})
    if not rows:
        for p in sorted(summary_path.parent.glob(f"*/{glob_suffix}")):
            m = read_json(p, quiet=True)
            if isinstance(m, dict): rows.append(m)
    return pd.DataFrame(rows)

def normalize_dict(payload):
    if payload is None: return None
    if isinstance(payload, dict):
        try: return pd.json_normalize(payload)
        except Exception: return pd.DataFrame([{"key": k, "value": v} for k, v in payload.items()])
    if isinstance(payload, list): return pd.DataFrame(payload)
    return pd.DataFrame([{"value": payload}])
# Out:
# Experiment : /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/results/experiments/data_tim_milan_10min_trainable_200_ctx144_h48/q50_q95_seed42
# Reports    : /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/results/experiments/data_tim_milan_10min_trainable_200_ctx144_h48/q50_q95_seed42/reports

# %% [markdown]
# ## 1. Overview

# %%
manifest = read_json(EXPERIMENT_DIR / "manifest.json", quiet=True)
if manifest:
    display(normalize_dict(manifest))

status = read_json(REPORTS_DIR / "stage_status.json", quiet=True)
if isinstance(status, dict) and status.get("stages"):
    md("### Stage Status")
    display(pd.DataFrame(status["stages"]).T)
# Out:
#                                   dataset_path timestamp_col cadence  \
# 0  data/data_tim_milan_10min_trainable_200.csv     timestamp   10min
#
#    random_seed  context_length  horizon    quantiles  train_ratio  val_ratio  \
# 0           42             144       48  [0.5, 0.95]          0.7        0.1
#
#    test_ratio  num_rows  num_series  \
# 0         0.2      8928         200
#
#                                       series_columns  \
# 0  [MI1, MI2, MI3, MI4, MI5, MI6, MI7, MI8, MI9, ...
#
#                      created_at_utc  train_split.start_idx  \
# 0  2026-03-23T19:59:50.626852+00:00                      0
#
#    train_split.end_idx  val_split.start_idx  val_split.end_idx  \
# 0                 6249                 6249               7142
#
#    test_split.start_idx  test_split.end_idx
# 0                  7142                8928
# ### Stage Status
#                          status                    started_at_utc  \
# prepare_data            success  2026-03-23T19:59:50.275558+00:00
# train                   success  2026-03-23T19:59:50.721686+00:00
# forecast_eval           success  2026-03-23T20:55:35.819142+00:00
# cp_sweep                success  2026-03-23T20:57:23.790748+00:00
# system_eval             success  2026-03-23T21:16:47.062311+00:00
# tau_calibration         success  2026-03-23T21:17:11.813234+00:00
# calibrated_system_eval  success  2026-03-23T21:30:38.595294+00:00
#
#                                          finished_at_utc duration_sec  \
# prepare_data            2026-03-23T19:59:50.721439+00:00        0.446
# train                   2026-03-23T20:55:35.818956+00:00     3345.078
# forecast_eval           2026-03-23T20:57:23.790355+00:00      107.971
# cp_sweep                2026-03-23T21:16:47.061857+00:00     1163.262
# system_eval             2026-03-23T21:17:11.812737+00:00        24.75
# tau_calibration         2026-03-23T21:30:38.594660+00:00      806.777
# calibrated_system_eval  2026-03-23T21:30:49.970647+00:00       11.375
#
#                                                                   command  \
# prepare_data            [/Users/colinminini/Desktop/SCOC_ICE/LLM6G-Rep...
# train                   [/Users/colinminini/Desktop/SCOC_ICE/LLM6G-Rep...
# forecast_eval           [/Users/colinminini/Desktop/SCOC_ICE/LLM6G-Rep...
# cp_sweep                [/Users/colinminini/Desktop/SCOC_ICE/LLM6G-Rep...
# system_eval             [/Users/colinminini/Desktop/SCOC_ICE/LLM6G-Rep...
# tau_calibration         [/Users/colinminini/Desktop/SCOC_ICE/LLM6G-Rep...
# calibrated_system_eval  [/Users/colinminini/Desktop/SCOC_ICE/LLM6G-Rep...
#
#                                                                   metrics  \
# prepare_data            {'dataset_path': 'data/data_tim_milan_10min_tr...
# train                   {'lstm': {'monitor_val_loss': 0.77938159463698...
# forecast_eval           {'val': {'chronos2': {'model': 'chronos2', 'sp...
# cp_sweep                {'best_break_f1_rows': [{'model': 'chronos2', ...
# system_eval             {'test': {'chronos2': {'model': 'chronos2', 's...
# tau_calibration         {'best_test_rows': [{'model': 'lstm', 'calibra...
# calibrated_system_eval  {'comparison_rows': [{'model': 'lstm', 'split'...
#
#                                                                     plots  \
# prepare_data            {'split_summary_plot': 'results/experiments/da...
# train                   {'training_loss_plot': 'results/experiments/da...
# forecast_eval           {'forecast_eval_test_plot': 'results/experimen...
# cp_sweep                {'cp_sweep_train_plot': 'results/experiments/d...
# system_eval             {'system_eval_test_plot': 'results/experiments...
# tau_calibration         {'tau_calibration_test_plot': 'results/experim...
# calibrated_system_eval  {'split_summary_plot': 'results/experiments/da...
#
#                                                              report_index  \
# prepare_data            results/experiments/data_tim_milan_10min_train...
# train                   results/experiments/data_tim_milan_10min_train...
# forecast_eval           results/experiments/data_tim_milan_10min_train...
# cp_sweep                results/experiments/data_tim_milan_10min_train...
# system_eval             results/experiments/data_tim_milan_10min_train...
# tau_calibration         results/experiments/data_tim_milan_10min_train...
# calibrated_system_eval  results/experiments/data_tim_milan_10min_train...
#
#                                                           published_plots
# prepare_data            {'split_summary_plot': '/Users/colinminini/Des...
# train                   {'split_summary_plot': '/Users/colinminini/Des...
# forecast_eval           {'example_windows_chronos2_test_plot': '/Users...
# cp_sweep                {'cp_sweep_train_plot': '/Users/colinminini/De...
# system_eval             {'cp_sweep_train_plot': '/Users/colinminini/De...
# tau_calibration         {'cp_sweep_train_plot': '/Users/colinminini/De...
# calibrated_system_eval  {'calibrated_system_eval_test_plot': '/Users/c...

# %% [markdown]
# ## 2. Data Split

# %%
show_table(EXPERIMENT_DIR / "split_summary.csv")
show_png(REPORTS_DIR / "prepare_data_split_summary.png")
# Out:
#    split  start_idx  end_idx  num_rows
# 0  train          0     6249      6249
# 1    val       6249     7142       893
# 2   test       7142     8928      1786

# %% [markdown]
# ## 3. Training

# %%
training_summary = read_json(EXPERIMENT_DIR / "training" / "training_summary.json", quiet=True)
if training_summary:
    display(normalize_dict(training_summary))

# ── training curves ───────────────────────────────────────────────────────
history_paths = sorted((EXPERIMENT_DIR / "training").glob("*_history.json"))
histories = {}
for p in history_paths:
    h = read_json(p, quiet=True)
    if isinstance(h, dict):
        histories[p.stem.replace("_history", "")] = h

if histories:
    metric_specs = [("loss", "Loss"), ("rmse", "RMSE"), ("coverage", "Coverage"), ("interval_width", "Interval Width")]
    fig, axes = plt.subplots(2, 2, figsize=(14, 8), constrained_layout=True)
    for ax, (key, title) in zip(axes.flat, metric_specs):
        for model, history in histories.items():
            x = history.get("iteration") or list(range(1, 100))
            for split, ls in [("train", "-"), ("val", "--")]:
                vals = history.get(f"{split}_{key}", [])
                if vals:
                    ax.plot(x[:len(vals)], vals, linestyle=ls, marker="o", markersize=3, linewidth=1.5, label=f"{model} {split}")
        ax.set_title(title); ax.set_xlabel("Iteration"); ax.grid(alpha=0.3)
        ax.legend(fontsize=7, ncol=2)
        if key == "coverage":
            ax.axhline(0.95, color="#d62728", linestyle=":", linewidth=1.2, label="target")
    display(fig); plt.close(fig)
else:
    for metric in ["training_loss", "training_rmse", "training_coverage", "training_interval_width"]:
        show_png(REPORTS_DIR / f"{metric}.png")
# Out:
#                                        manifest_path device  \
# 0  results/experiments/data_tim_milan_10min_train...    mps
#
#                             models.lstm.history_path  \
# 0  results/experiments/data_tim_milan_10min_train...
#
#                          models.lstm.checkpoint_path  \
# 0  results/experiments/data_tim_milan_10min_train...
#
#    models.lstm.max_iterations  models.lstm.patience_iterations  \
# 0                       94710                             9471
#
#    models.lstm.validate_epochs  models.lstm.validate_every  \
# 0                            1                        3157
#
#    models.lstm.train_window_step  \
# 0                              6
#
#    models.lstm.training_schedule.steps_per_epoch  ...  \
# 0                                           3157  ...
#
#    models.tft.monitor_metrics.monitor_val_loss  \
# 0                                     0.741133
#
#    models.tft.monitor_metrics.monitor_val_rmse  \
# 0                                     5.905675
#
#    models.tft.monitor_metrics.val.rmse_q50  \
# 0                                 5.905675
#
#    models.tft.monitor_metrics.val.pinball_q50  \
# 0                                    1.133808
#
#   models.tft.monitor_metrics.val.pinball_q95  \
# 0                                    0.34759
#
#   models.tft.monitor_metrics.val.coverage_q95  \
# 0                                    0.906181
#
#   models.tft.monitor_metrics.val.interval_width_mean  \
# 0                                           3.914345
#
#    models.tft.monitor_metrics.best_val  \
# 0                             1.357324
#
#    models.tft.monitor_metrics.last_iteration  \
# 0                                      12628
#
#    models.tft.monitor_metrics.monitor
# 0                             pinball
#
# [1 rows x 77 columns]

# %% [markdown]
# ## 4. Forecast Evaluation

# %%
fm = discover_metrics(EXPERIMENT_DIR / "forecast_eval/forecast_eval_summary.json", "*_forecast_metrics.json")
if not fm.empty:
    cols = ["split", "model", "num_windows_total", "rmse_q50", "pinball_q50", "pinball_q95", "coverage_q95", "interval_width_mean"]
    display(fm[[c for c in cols if c in fm.columns]].sort_values(["split", "model"]).reset_index(drop=True))

show_png(REPORTS_DIR / "forecast_eval_test.png", "Forecast Metrics — Test")
show_png(REPORTS_DIR / "forecast_eval_val.png",  "Forecast Metrics — Val")

md("### Forecast Example Windows (Test)")
MODELS = ["lstm", "deepar", "tft", "chronos2", "seasonal_naive"]
for model_name in MODELS:
    show_png(REPORTS_DIR / f"example_windows_{model_name}_test.png", model_name)
# Out:
#   split           model  num_windows_total  rmse_q50  pinball_q50  \
# 0  test        chronos2               7400  7.070477     2.108417
# 1  test          deepar               7400  5.796384     1.492793
# 2  test            lstm               7400  5.683938     1.388997
# 3  test  seasonal_naive               7400  7.262978     1.404979
# 4  test             tft               7400  5.657745     1.151777
# 5   val        chronos2               3600  7.229148     1.687570
# 6   val          deepar               3600  6.498159     1.637893
# 7   val            lstm               3600  6.322548     1.559320
# 8   val  seasonal_naive               3600  7.587165     1.472632
# 9   val             tft               3600  5.561610     1.129228
#
#    pinball_q95  coverage_q95  interval_width_mean
# 0     0.728333      0.813936             6.545527
# 1     0.817339      0.667278             2.885249
# 2     0.385309      0.950563             5.234861
# 3     0.488935      0.857810             4.497222
# 4     0.356804      0.923801             4.417264
# 5     0.521602      0.949323             8.097793
# 6     0.884172      0.668611             3.189140
# 7     0.438767      0.940469             5.629103
# 8     0.521552      0.854549             5.072770
# 9     0.315392      0.950260             4.783954
# ### Forecast Metrics — Test
# ### Forecast Metrics — Val
# ### Forecast Example Windows (Test)
# ### lstm
# ### deepar
# ### tft
# ### chronos2
# ### seasonal_naive

# %% [markdown]
# ## 5. System Evaluation

# %%
sm = discover_metrics(EXPERIMENT_DIR / "system_eval/system_eval_summary.json", "*_system_metrics.json")
if not sm.empty:
    cols = ["split", "model", "num_windows_total", "MAE_CP", "tolerance", "tolerance_hit_rate", "coverage_rate", "sharpness"]
    display(sm[[c for c in cols if c in sm.columns]].sort_values(["split", "model"]).reset_index(drop=True))

show_png(REPORTS_DIR / "system_eval_test.png", "System Metrics — Test")

md("### Pipeline Example Windows — All Models (Test)")
MODELS = ["lstm", "deepar", "tft", "chronos2", "seasonal_naive"]
for model_name in MODELS:
    show_png(REPORTS_DIR / f"example_windows_system_eval_{model_name}_test.png", model_name)
# Out:
#   split           model  num_windows_total    MAE_CP  tolerance  \
# 0  test        chronos2               7400  7.415405          3
# 1  test          deepar               7400  7.161892          3
# 2  test            lstm               7400  7.174595          3
# 3  test  seasonal_naive               7400  7.332973          3
# 4  test             tft               7400  7.385676          3
#
#    tolerance_hit_rate  coverage_rate  sharpness
# 0            0.420135       0.873324   1.148236
# 1            0.426486       0.801810  -1.064178
# 2            0.487162       0.983800   2.794287
# 3            0.426757       0.973306   4.879403
# 4            0.461622       0.968115   2.094669
# ### System Metrics — Test
# ### Pipeline Example Windows — All Models (Test)
# ### lstm
# ### deepar
# ### tft
# ### chronos2
# ### seasonal_naive

# %% [markdown]
# ## 6. Change-Point Sweep

# %%
show_png(REPORTS_DIR / "cp_sweep_train.png", "CP Sweep Heatmap — Train")

md("### Best Configs")
show_table(EXPERIMENT_DIR / "cp_sweep/train/cp_sweep_best_configs.csv")
# Out:
# ### CP Sweep Heatmap — Train
# ### Best Configs
#             model  split                              forecast_windows_path  \
# 0        chronos2  train  results/experiments/data_tim_milan_10min_train...
# 1          deepar  train  results/experiments/data_tim_milan_10min_train...
# 2            lstm  train  results/experiments/data_tim_milan_10min_train...
# 3  seasonal_naive  train  results/experiments/data_tim_milan_10min_train...
# 4             tft  train  results/experiments/data_tim_milan_10min_train...
#
#   cp_detector  cp_min_size  cp_period_length  cp_exclusion_radius  \
# 0       clasp            8                16                 0.05
# 1       clasp            8                16                 0.05
# 2       clasp            8                16                 0.05
# 3       clasp            8                16                 0.05
# 4       clasp            8                16                 0.05
#
#    cp_score_threshold cp_model  cp_penalty  ...  tolerance  \
# 0                 0.5   normal        10.0  ...          3
# 1                 0.5   normal        10.0  ...          3
# 2                 0.5   normal        10.0  ...          3
# 3                 0.5   normal        10.0  ...          3
# 4                 0.5   normal        10.0  ...          3
#
#    tolerance_hit_rate  tolerance_hit_rate_when_both_break  break_precision  \
# 0              0.4718                              0.4718              1.0
# 1              0.5109                              0.5109              1.0
# 2              0.5259                              0.5259              1.0
# 3              0.4930                              0.4930              1.0
# 4              0.5668                              0.5668              1.0
#
#    break_recall  break_f1  coverage_rate  sharpness  coverage_gap  \
# 0           1.0       1.0       0.922165   1.667404      0.027835
# 1           1.0       1.0       0.833263  -4.258384      0.116737
# 2           1.0       1.0       0.958283  -0.727442      0.008283
# 3           1.0       1.0       0.977503   5.406620      0.027503
# 4           1.0       1.0       0.962322  -0.970259      0.012322
#
#    selection_rule
# 0   best_break_f1
# 1   best_break_f1
# 2   best_break_f1
# 3   best_break_f1
# 4   best_break_f1
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 7. Tau Calibration

# %%
tau_dir = EXPERIMENT_DIR / "tau_calibration"
if (tau_dir / "tau_calibration_summary.csv").exists():
    show_table(tau_dir / "tau_calibration_best_test_rows.csv", "Best Calibrators (Test)")
    show_png(REPORTS_DIR / "tau_calibration_test.png", "Tau Calibration — Test")
    show_png(REPORTS_DIR / "tau_calibration_feature_importance.png", "Feature Importance")
else:
    note("Tau calibration not run. Use `--with-tau-calibration` to generate.")
# Out:
# ### Best Calibrators (Test)
#              model                calibrator split cp_detector cp_model  \
# 0             lstm      global_median_offset  test       clasp   normal
# 1             lstm      global_median_offset  test       clasp   normal
# 2             lstm  per_series_median_offset  test       clasp   normal
# 3             lstm                   raw_tau  test       clasp   normal
# 4           deepar      global_median_offset  test       clasp   normal
# 5           deepar  per_series_median_offset  test       clasp   normal
# 6           deepar               extra_trees  test       clasp   normal
# 7           deepar                   raw_tau  test       clasp   normal
# 8              tft      global_median_offset  test       clasp   normal
# 9              tft      global_median_offset  test       clasp   normal
# 10             tft      global_median_offset  test       clasp   normal
# 11             tft                   raw_tau  test       clasp   normal
# 12        chronos2      global_median_offset  test       clasp   normal
# 13        chronos2      global_median_offset  test       clasp   normal
# 14        chronos2      global_median_offset  test       clasp   normal
# 15        chronos2                   raw_tau  test       clasp   normal
# 16  seasonal_naive      global_median_offset  test       clasp   normal
# 17  seasonal_naive      global_median_offset  test       clasp   normal
# 18  seasonal_naive      global_median_offset  test       clasp   normal
# 19  seasonal_naive                   raw_tau  test       clasp   normal
#
#     cp_penalty  cp_min_size  cp_jump  cp_period_length  cp_exclusion_radius  \
# 0         10.0            8        1                16                 0.05
# 1         10.0            8        1                16                 0.05
# 2         10.0            8        1                16                 0.05
# 3         10.0            8        1                16                 0.05
# 4         10.0            8        1                16                 0.05
# 5         10.0            8        1                16                 0.05
# 6         10.0            8        1                16                 0.05
# 7         10.0            8        1                16                 0.05
# 8         10.0            8        1                16                 0.05
# 9         10.0            8        1                16                 0.05
# 10        10.0            8        1                16                 0.05
# 11        10.0            8        1                16                 0.05
# 12        10.0            8        1                16                 0.05
# 13        10.0            8        1                16                 0.05
# 14        10.0            8        1                16                 0.05
# 15        10.0            8        1                16                 0.05
# 16        10.0            8        1                16                 0.05
# 17        10.0            8        1                16                 0.05
# 18        10.0            8        1                16                 0.05
# 19        10.0            8        1                16                 0.05
#
#     ...  tolerance_hit_rate  mean_signed_error  coverage_rate  sharpness  \
# 0   ...            0.487162           1.871892       0.983800   2.794287
# 1   ...            0.487162           1.871892       0.983800   2.794287
# 2   ...            0.469189           1.641892       0.982983   2.641115
# 3   ...            0.487162           1.871892       0.983800   2.794287
# 4   ...            0.426486          -2.737027       0.801810  -1.064178
# 5   ...            0.426081          -2.882027       0.801370  -1.067711
# 6   ...            0.103378          -1.432838       0.807835  -1.000401
# 7   ...            0.426486          -2.737027       0.801810  -1.064178
# 8   ...            0.461622          -6.474054       0.968115   2.094669
# 9   ...            0.461622          -6.474054       0.968115   2.094669
# 10  ...            0.461622          -6.474054       0.968115   2.094669
# 11  ...            0.461622          -6.474054       0.968115   2.094669
# 12  ...            0.420135          -2.223243       0.873324   1.148236
# 13  ...            0.420135          -2.223243       0.873324   1.148236
# 14  ...            0.420135          -2.223243       0.873324   1.148236
# 15  ...            0.420135          -2.223243       0.873324   1.148236
# 16  ...            0.426757           0.217297       0.973306   4.879403
# 17  ...            0.426757           0.217297       0.973306   4.879403
# 18  ...            0.426757           0.217297       0.973306   4.879403
# 19  ...            0.426757           0.217297       0.973306   4.879403
#
#     delta_MAE_CP  delta_tolerance_hit_rate  delta_coverage_rate  \
# 0       0.000000                  0.000000             0.000000
# 1       0.000000                  0.000000             0.000000
# 2       0.146757                 -0.017973            -0.000817
# 3       0.000000                  0.000000             0.000000
# 4       0.000000                  0.000000             0.000000
# 5       0.019595                 -0.000405            -0.000440
# 6      -0.373378                 -0.323108             0.006025
# 7       0.000000                  0.000000             0.000000
# 8       0.000000                  0.000000             0.000000
# 9       0.000000                  0.000000             0.000000
# 10      0.000000                  0.000000             0.000000
# 11      0.000000                  0.000000             0.000000
# 12      0.000000                  0.000000             0.000000
# 13      0.000000                  0.000000             0.000000
# 14      0.000000                  0.000000             0.000000
# 15      0.000000                  0.000000             0.000000
# 16      0.000000                  0.000000             0.000000
# 17      0.000000                  0.000000             0.000000
# 18      0.000000                  0.000000             0.000000
# 19      0.000000                  0.000000             0.000000
#
#     delta_sharpness  coverage_gap                  selected_on
# 0          0.000000      0.033800              best_val_mae_cp
# 1          0.000000      0.033800  best_val_tolerance_hit_rate
# 2         -0.153172      0.032983         closest_val_coverage
# 3          0.000000      0.033800            raw_test_baseline
# 4          0.000000      0.148190              best_val_mae_cp
# 5         -0.003533      0.148630  best_val_tolerance_hit_rate
# 6          0.063778      0.142165         closest_val_coverage
# 7          0.000000      0.148190            raw_test_baseline
# 8          0.000000      0.018115              best_val_mae_cp
# 9          0.000000      0.018115  best_val_tolerance_hit_rate
# 10         0.000000      0.018115         closest_val_coverage
# 11         0.000000      0.018115            raw_test_baseline
# 12         0.000000      0.076676              best_val_mae_cp
# 13         0.000000      0.076676  best_val_tolerance_hit_rate
# 14         0.000000      0.076676         closest_val_coverage
# 15         0.000000      0.076676            raw_test_baseline
# 16         0.000000      0.023306              best_val_mae_cp
# 17         0.000000      0.023306  best_val_tolerance_hit_rate
# 18         0.000000      0.023306         closest_val_coverage
# 19         0.000000      0.023306            raw_test_baseline
#
# [20 rows x 23 columns]
# ### Tau Calibration — Test
# ### Feature Importance
# > PNG not found: `results/experiments/data_tim_milan_10min_trainable_200_ctx144_h48/q50_q95_seed42/reports/tau_calibration_feature_importance.png`

# %% [markdown]
# ## 8. Calibrated System Evaluation

# %%
if CALIBRATED_PATH.exists():
    show_table(CALIBRATED_PATH, "Raw vs Calibrated Metrics")
    show_png(REPORTS_DIR / "calibrated_system_eval_test.png", "Calibrated System Eval — Test")
else:
    note("Calibrated system-eval not run. Re-run pipeline with `--with-tau-calibration`.")
# Out:
# ### Raw vs Calibrated Metrics
#             model split   selected_calibrator   selection_rule  raw_MAE_CP  \
# 0            lstm  test  global_median_offset  best_val_mae_cp    7.174595
# 1          deepar  test  global_median_offset  best_val_mae_cp    7.161892
# 2             tft  test  global_median_offset  best_val_mae_cp    7.385676
# 3        chronos2  test  global_median_offset  best_val_mae_cp    7.415405
# 4  seasonal_naive  test  global_median_offset  best_val_mae_cp    7.332973
#
#    calibrated_MAE_CP  delta_MAE_CP  raw_tolerance_hit_rate  \
# 0           7.174595           0.0                0.487162
# 1           7.161892           0.0                0.426486
# 2           7.385676           0.0                0.461622
# 3           7.415405           0.0                0.420135
# 4           7.332973           0.0                0.426757
#
#    calibrated_tolerance_hit_rate  delta_tolerance_hit_rate  raw_coverage_rate  \
# 0                       0.487162                       0.0           0.983800
# 1                       0.426486                       0.0           0.801810
# 2                       0.461622                       0.0           0.968115
# 3                       0.420135                       0.0           0.873324
# 4                       0.426757                       0.0           0.973306
#
#    calibrated_coverage_rate  delta_coverage_rate  raw_sharpness  \
# 0                  0.983800                  0.0       2.794287
# 1                  0.801810                  0.0      -1.064178
# 2                  0.968115                  0.0       2.094669
# 3                  0.873324                  0.0       1.148236
# 4                  0.973306                  0.0       4.879403
#
#    calibrated_sharpness  delta_sharpness
# 0              2.794287              0.0
# 1             -1.064178              0.0
# 2              2.094669              0.0
# 3              1.148236              0.0
# 4              4.879403              0.0
# ### Calibrated System Eval — Test
