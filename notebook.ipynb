# %% [markdown]
# ## The Sketching Notebook, for current work ideas

# %%
from scripts.train_run import train_model

lstm_history = train_model("lstm", dataset_base="data_original", max_epochs=100, context_length=12)

# tensorboard --logdir ./logs
# Out:
# Epoch 1/100 - train_loss=203.295306 - train_rmse=14.260212 - val_loss=292.612640 - val_rmse=17.724407 - test_rmse=16.394813 - best_val=292.612640 - patience=0/3
# Epoch 2/100 - train_loss=80.461653 - train_rmse=8.971043 - val_loss=170.527283 - val_rmse=13.764881 - test_rmse=12.386072 - best_val=170.527283 - patience=0/3
# Epoch 3/100 - train_loss=50.567891 - train_rmse=7.109815 - val_loss=119.927124 - val_rmse=11.757771 - test_rmse=10.361223 - best_val=119.927124 - patience=0/3
# Epoch 4/100 - train_loss=37.858714 - train_rmse=6.154362 - val_loss=92.602552 - val_rmse=10.522411 - test_rmse=8.957383 - best_val=92.602552 - patience=0/3
# Epoch 5/100 - train_loss=31.043101 - train_rmse=5.570314 - val_loss=77.978279 - val_rmse=9.837816 - test_rmse=8.157418 - best_val=77.978279 - patience=0/3
# Epoch 6/100 - train_loss=27.155860 - train_rmse=5.212007 - val_loss=65.302190 - val_rmse=9.053876 - test_rmse=7.419672 - best_val=65.302190 - patience=0/3
# ...

# %%
from scripts.train_run import train_model

patchTST_history = train_model("patchTST", dataset_base="data_original", max_epochs=100, context_length=12, patch_len=12)

# tensorboard --logdir ./results/logs
# Out:
# Epoch 1/100 - train_loss=210.348400 - train_rmse=14.504842 - val_loss=365.843262 - val_rmse=19.548430 - test_rmse=18.431025 - best_val=365.843262 - patience=0/3
# Epoch 2/100 - train_loss=117.755666 - train_rmse=10.853389 - val_loss=163.763748 - val_rmse=13.497797 - test_rmse=12.357360 - best_val=163.763748 - patience=0/3
# Epoch 3/100 - train_loss=57.413863 - train_rmse=7.577962 - val_loss=97.596750 - val_rmse=10.722130 - test_rmse=9.360292 - best_val=97.596750 - patience=0/3
# Epoch 4/100 - train_loss=44.038005 - train_rmse=6.637142 - val_loss=69.344452 - val_rmse=9.247712 - test_rmse=7.771526 - best_val=69.344452 - patience=0/3
# Epoch 5/100 - train_loss=35.754729 - train_rmse=5.980011 - val_loss=105.876904 - val_rmse=10.916637 - test_rmse=10.179176 - best_val=69.344452 - patience=1/3
# Epoch 6/100 - train_loss=31.598070 - train_rmse=5.621528 - val_loss=68.649435 - val_rmse=9.042367 - test_rmse=8.195194 - best_val=68.649435 - patience=0/3
# ...

# %%
# Chronos-2 RMSE evaluation on the input dataset
# !python3 scripts/chronos2_eval.py --data-path data/datasets/data_original_train.csv --context-length 12
# Out:
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# RMSE: 3.919182
# Saved results to results/evals/chronos2_test_rmse.json
