# %% [markdown]
# ## The Sketching Notebook, for current work ideas

# %%
# Colab setup: clone repo and install dependencies
import sys
from pathlib import Path

if 'google.colab' in sys.modules:
    repo_path = Path('/content/LLM6G-Repository')
    if not repo_path.exists():
        # !git clone https://github.com/colinminini/LLM6G-Repository.git
    # %cd /content/LLM6G-Repository
    # %pip install -r requirements.txt

# %%
from scripts.train_run import train_model

lstm_history = train_model("lstm", dataset_base="data_instant", max_epochs=10)

# %%
# Chronos-2 RMSE evaluation on the test split
# !python3 scripts/chronos2_eval.py
