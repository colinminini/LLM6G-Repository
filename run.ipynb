# %%
# !python src/run_experiment.py \
  --overwrite \
  --with-tau-calibration \
  --data-path data/data_1to672.csv \
  --context-length 96 \
  --horizon 48 \
  --models lstm,deepar,chronos2 \
  --max-iterations 10000 \
  --patience-iterations 1000 \
  --validate-every 5000 \
  --log-every 1000
# Out:
# ================================================================================
# Stage 1/7: prepare_data
# Output dir: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42
# ================================================================================
# Saved manifest: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/manifest.json
# Saved split summary: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/split_summary.csv
# Completed prepare_data in 0.6s
# Headline metrics: {"dataset_path": "data/data_1to672.csv", "context_length": 96, "horizon": 48, "num_rows": 131712, "num_series": 29}
#
# ================================================================================
# Stage 2/7: train
# Output dir: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42
# ================================================================================
# [train:lstm] starting max_iterations=10000 validate_every=5000 patience_iterations=1000
# [lstm_data_1to672] train iter 1/10000 batch_loss=9.593
# [lstm_data_1to672] train iter 1000/10000 batch_loss=0.765
# [lstm_data_1to672] train iter 2000/10000 batch_loss=0.473
# [lstm_data_1to672] train iter 3000/10000 batch_loss=0.402
# [lstm_data_1to672] train iter 4000/10000 batch_loss=0.379
# [lstm_data_1to672] train iter 5000/10000 batch_loss=0.557
# [lstm_data_1to672] val batch 1000 step=5000 loss=1.675
# [lstm_data_1to672] val batch 2000 step=5000 loss=0.490
# [lstm_data_1to672] val batch 3000 step=5000 loss=0.797
# [lstm_data_1to672] val batch 4000 step=5000 loss=0.580
# [lstm_data_1to672] val batch 5000 step=5000 loss=1.349
# [lstm_data_1to672] test batch 1000 step=5000 loss=0.704
# [lstm_data_1to672] test batch 2000 step=5000 loss=1.836
# [lstm_data_1to672] test batch 3000 step=5000 loss=0.638
# [lstm_data_1to672] test batch 4000 step=5000 loss=0.402
# [lstm_data_1to672] test batch 5000 step=5000 loss=8.165
# [lstm_data_1to672] test batch 6000 step=5000 loss=0.492
# [lstm_data_1to672] test batch 7000 step=5000 loss=0.831
# [lstm_data_1to672] test batch 8000 step=5000 loss=0.698
# [lstm_data_1to672] test batch 9000 step=5000 loss=0.211
# [lstm_data_1to672] test batch 10000 step=5000 loss=7.623
# [lstm_data_1to672] test batch 11000 step=5000 loss=1.301
# [lstm_data_1to672] iter 5000/10000 - train_loss=0.910 - train_rmse=4.707 - val_loss=0.735 - val_rmse=3.363 - test_loss=1.138 - test_rmse=5.403 - patience_iters=0/1000
# [lstm_data_1to672] train iter 6000/10000 batch_loss=0.344
# [lstm_data_1to672] train iter 7000/10000 batch_loss=0.469
# [lstm_data_1to672] train iter 8000/10000 batch_loss=0.414
# [lstm_data_1to672] train iter 9000/10000 batch_loss=0.358
# [lstm_data_1to672] train iter 10000/10000 batch_loss=0.296
# [lstm_data_1to672] val batch 1000 step=10000 loss=1.154
# [lstm_data_1to672] val batch 2000 step=10000 loss=0.457
# [lstm_data_1to672] val batch 3000 step=10000 loss=0.742
# [lstm_data_1to672] val batch 4000 step=10000 loss=0.589
# [lstm_data_1to672] val batch 5000 step=10000 loss=1.280
# [lstm_data_1to672] test batch 1000 step=10000 loss=0.712
# [lstm_data_1to672] test batch 2000 step=10000 loss=1.371
# [lstm_data_1to672] test batch 3000 step=10000 loss=0.652
# [lstm_data_1to672] test batch 4000 step=10000 loss=0.493
# [lstm_data_1to672] test batch 5000 step=10000 loss=6.147
# [lstm_data_1to672] test batch 6000 step=10000 loss=0.463
# [lstm_data_1to672] test batch 7000 step=10000 loss=0.858
# [lstm_data_1to672] test batch 8000 step=10000 loss=0.701
# [lstm_data_1to672] test batch 9000 step=10000 loss=0.221
# [lstm_data_1to672] test batch 10000 step=10000 loss=5.946
# [lstm_data_1to672] test batch 11000 step=10000 loss=1.427
# [lstm_data_1to672] iter 10000/10000 - train_loss=0.441 - train_rmse=2.147 - val_loss=0.710 - val_rmse=3.253 - test_loss=1.022 - test_rmse=5.034 - patience_iters=0/1000
# Final metrics
#                   metric   value
# 0             train_loss   0.441
# 1             train_rmse   2.147
# 2               val_loss   0.710
# 3               val_rmse   3.253
# 4             train_q0.5   0.692
# 5            train_q0.95   0.190
# 6               val_q0.5   1.113
# 7              val_q0.95   0.306
# 8         train_coverage   0.950
# 9           val_coverage   0.947
# 10     coverage_quantile   0.950
# 11  train_interval_width   2.933
# 12    val_interval_width   4.767
# 13             test_loss   1.022
# 14             test_rmse   5.034
# 15             test_q0.5   1.481
# 16            test_q0.95   0.563
# 17         test_coverage   0.917
# 18   test_interval_width   5.317
# 19              best_val   0.710
# 20        last_iteration   10000
# 21   patience_iterations  0/1000
# 22               monitor    loss
# [train:deepar] starting max_iterations=10000 validate_every=5000 patience_iterations=1000
# [deepar_data_1to672] train iter 1/10000 batch_loss=3.790
# [deepar_data_1to672] train iter 1000/10000 batch_loss=0.747
# [deepar_data_1to672] train iter 2000/10000 batch_loss=0.928
# [deepar_data_1to672] train iter 3000/10000 batch_loss=0.921
# [deepar_data_1to672] train iter 4000/10000 batch_loss=0.933
# [deepar_data_1to672] train iter 5000/10000 batch_loss=0.935
# [deepar_data_1to672] val batch 1000 step=5000 loss=1.962
# [deepar_data_1to672] val batch 2000 step=5000 loss=1.351
# [deepar_data_1to672] val batch 3000 step=5000 loss=1.539
# [deepar_data_1to672] val batch 4000 step=5000 loss=1.571
# [deepar_data_1to672] val batch 5000 step=5000 loss=2.485
# [deepar_data_1to672] test batch 1000 step=5000 loss=1.654
# [deepar_data_1to672] test batch 2000 step=5000 loss=2.123
# [deepar_data_1to672] test batch 3000 step=5000 loss=1.618
# [deepar_data_1to672] test batch 4000 step=5000 loss=1.288
# [deepar_data_1to672] test batch 5000 step=5000 loss=2.505
# [deepar_data_1to672] test batch 6000 step=5000 loss=1.435
# [deepar_data_1to672] test batch 7000 step=5000 loss=1.802
# [deepar_data_1to672] test batch 8000 step=5000 loss=1.784
# [deepar_data_1to672] test batch 9000 step=5000 loss=0.545
# [deepar_data_1to672] test batch 10000 step=5000 loss=2.710
# [deepar_data_1to672] test batch 11000 step=5000 loss=1.788
# [deepar_data_1to672] iter 5000/10000 - train_loss=0.916 - train_rmse=1.127 - val_loss=1.406 - val_rmse=1.365 - test_loss=1.477 - test_rmse=1.620 - patience_iters=0/1000
# [deepar_data_1to672] train iter 6000/10000 batch_loss=0.771
# [deepar_data_1to672] train iter 7000/10000 batch_loss=0.778
# [deepar_data_1to672] train iter 8000/10000 batch_loss=0.809
# [deepar_data_1to672] train iter 9000/10000 batch_loss=0.906
# [deepar_data_1to672] train iter 10000/10000 batch_loss=0.900
# [deepar_data_1to672] val batch 1000 step=10000 loss=1.859
# [deepar_data_1to672] val batch 2000 step=10000 loss=1.328
# [deepar_data_1to672] val batch 3000 step=10000 loss=1.536
# [deepar_data_1to672] val batch 4000 step=10000 loss=1.537
# [deepar_data_1to672] val batch 5000 step=10000 loss=2.429
# [deepar_data_1to672] test batch 1000 step=10000 loss=1.626
# [deepar_data_1to672] test batch 2000 step=10000 loss=2.024
# [deepar_data_1to672] test batch 3000 step=10000 loss=1.635
# [deepar_data_1to672] test batch 4000 step=10000 loss=1.245
# [deepar_data_1to672] test batch 5000 step=10000 loss=2.509
# [deepar_data_1to672] test batch 6000 step=10000 loss=1.426
# [deepar_data_1to672] test batch 7000 step=10000 loss=1.790
# [deepar_data_1to672] test batch 8000 step=10000 loss=1.772
# [deepar_data_1to672] test batch 9000 step=10000 loss=0.559
# [deepar_data_1to672] test batch 10000 step=10000 loss=2.638
# [deepar_data_1to672] test batch 11000 step=10000 loss=1.616
# [deepar_data_1to672] iter 10000/10000 - train_loss=0.814 - train_rmse=0.889 - val_loss=1.388 - val_rmse=1.335 - test_loss=1.459 - test_rmse=1.581 - patience_iters=0/1000
# Final metrics
#                   metric   value
# 0             train_loss   0.814
# 1             train_rmse   0.889
# 2               val_loss   1.388
# 3               val_rmse   1.335
# 4             train_q0.5   0.290
# 5            train_q0.95   0.076
# 6               val_q0.5   0.466
# 7              val_q0.95   0.124
# 8         train_coverage   0.950
# 9           val_coverage   0.965
# 10     coverage_quantile   0.950
# 11  train_interval_width   1.197
# 12    val_interval_width   2.037
# 13             test_loss   1.459
# 14             test_rmse   1.581
# 15             test_q0.5   0.535
# 16            test_q0.95   0.141
# 17         test_coverage   0.966
# 18   test_interval_width   2.340
# 19              best_val   1.388
# 20        last_iteration   10000
# 21   patience_iterations  0/1000
# 22               monitor    loss
# Saved training summary: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/training/training_summary.json
# Completed train in 2849.1s
# Headline metrics: {"lstm": {"val_loss_last": 0.7098372494581068, "test_rmse_last": 5.033843291634568}, "deepar": {"val_loss_last": 1.3882504945333682, "test_rmse_last": 1.581046227422748}}
#
# ================================================================================
# Stage 3/7: forecast_eval
# Output dir: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42
# ================================================================================
# [forecast_eval:train:lstm] rmse_q50=2.1250 coverage_q95=0.9461
# [forecast_eval:train:deepar] rmse_q50=2.1803 coverage_q95=0.8571
# [forecast_eval:train:chronos2] rmse_q50=2.4711 coverage_q95=0.9506
# [forecast_eval:val:lstm] rmse_q50=3.2351 coverage_q95=0.9425
# [forecast_eval:val:deepar] rmse_q50=3.2378 coverage_q95=0.8341
# [forecast_eval:val:chronos2] rmse_q50=3.6908 coverage_q95=0.9443
# [forecast_eval:test:lstm] rmse_q50=5.1262 coverage_q95=0.9157
# [forecast_eval:test:deepar] rmse_q50=3.6838 coverage_q95=0.8369
# [forecast_eval:test:chronos2] rmse_q50=4.2829 coverage_q95=0.9472
# Saved forecast summary: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/forecast_eval/forecast_eval_summary.json
# Completed forecast_eval in 146.1s
# Headline metrics: {"train": {"chronos2": {"model": "chronos2", "split": "train", "dataset_path": "data/data_1to672.csv", "context_length": 96, "horizon": 48, "quantiles": [0.5, 0.95], "num_windows_total": 1450, "rmse_q50": 2.471124320875778, "pinball_q50": 0.7906554112074922, "pinball_q95": 0.23567331313414186, "coverage_q95": 0.9506178160919541, "interval_width_mean": 3.877040522274101}, "deepar": {"model": "deepar", "split": "train", "dataset_path": "data/data_1to672.csv", "context_length": 96, "horizon": 48, "quantiles": [0.5, 0.95], "num_windows_total": 1450, "rmse_q50": 2.1803322452043945, "pinball_q50": 0
#
# ================================================================================
# Stage 4/7: system_eval
# Output dir: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42
# ================================================================================
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# [system_eval:test:lstm] MAE_CP=6.8007 coverage=0.9406
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# [system_eval:test:deepar] MAE_CP=6.7697 coverage=0.8953
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# [system_eval:test:chronos2] MAE_CP=6.7800 coverage=0.9647
# Saved system summary: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/system_eval/system_eval_summary.json
# Completed system_eval in 26.7s
# Headline metrics: {"test": {"chronos2": {"model": "chronos2", "split": "test", "timestamp_utc": "2026-03-21T12:13:34.230691+00:00", "num_windows_total": 1450, "MAE_CP": 6.78, "tolerance": 3, "tolerance_hit_rate": 0.44275862068965516, "coverage_rate": 0.9646927995551848, "sharpness": 3.300110082084591, "cp_detector": {"model": "normal", "penalty": 10.0, "min_size": 8, "jump": 1}}, "deepar": {"model": "deepar", "split": "test", "timestamp_utc": "2026-03-21T12:13:26.599895+00:00", "num_windows_total": 1450, "MAE_CP": 6.769655172413793, "tolerance": 3, "tolerance_hit_rate": 0.4579310344827586, "coverage_rate": 0.89
#
# ================================================================================
# Stage 5/7: cp_sweep
# Output dir: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42
# ================================================================================
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# Saved sweep summary: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/cp_sweep/val/cp_sweep_summary.csv
# Saved best configs: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/cp_sweep/val/cp_sweep_best_configs.csv
# Saved sweep manifest: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/cp_sweep/val/cp_sweep_manifest.json
# Completed cp_sweep in 256.7s
# Headline metrics: {"best_mae_rows": [{"model": "chronos2", "split": "val", "forecast_windows_path": "results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/forecast_eval/val/chronos2_forecast_windows.csv", "cp_model": "normal", "cp_penalty": 10.0, "cp_min_size": 8, "cp_jump": 1, "num_windows_total": 1450, "MAE_CP": 7.026896551724138, "tolerance": 3, "tolerance_hit_rate": 0.4, "coverage_rate": 0.966088579361828, "sharpness": 2.804935991348758, "coverage_gap": 0.016088579361828}, {"model": "deepar", "split": "val", "forecast_windows_path": "results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/forecast_eval/
#
# ================================================================================
# Stage 6/7: tau_calibration
# Output dir: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42
# ================================================================================
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/ruptures/costs/costnormal.py:28: UserWarning: New behaviour in v1.1.5: a small bias is added to the covariance matrix to cope with truly constant segments (see PR#198).
#   warnings.warn(
# Saved summary: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/tau_calibration/tau_calibration_summary.csv
# Saved best test rows: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/tau_calibration/tau_calibration_best_test_rows.csv
# Saved predictions: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/tau_calibration/tau_calibration_predictions.csv
# Saved test predictions: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/tau_calibration/tau_calibration_test_predictions.csv
# Saved feature importances: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/tau_calibration/tau_calibration_feature_importances.csv
# Saved manifest: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/tau_calibration/tau_calibration_manifest.json
# Completed tau_calibration in 118.5s
# Headline metrics: {"best_test_rows": [{"model": "lstm", "calibrator": "gradient_boosting", "split": "test", "cp_model": "normal", "cp_penalty": 10.0, "cp_min_size": 8, "cp_jump": 1, "num_windows": 1450, "MAE_CP": 6.548275862068966, "tolerance_hit_rate": 0.3089655172413793, "mean_signed_error": 1.1124137931034483, "coverage_rate": 0.9496339542211102, "sharpness": 2.2515830207208443, "delta_MAE_CP": -0.2524137931034476, "delta_tolerance_hit_rate": -0.1441379310344827, "delta_coverage_rate": 0.0090353072004447, "delta_sharpness": 0.5311169321783658, "coverage_gap": 0.0003660457788897, "selected_on": "best_val_mae_
#
# ================================================================================
# Stage 7/7: calibrated_system_eval
# Output dir: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42
# ================================================================================
# [calibrated_system_eval:test:lstm] calibrator=gradient_boosting MAE_CP=6.5448
# [calibrated_system_eval:test:deepar] calibrator=global_median_offset MAE_CP=5.6309
# [calibrated_system_eval:test:chronos2] calibrator=gradient_boosting MAE_CP=6.7163
# Saved calibrated system summary: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/calibrated_system_eval/calibrated_system_eval_summary.json
# Saved calibrated system comparison: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/calibrated_system_eval/calibrated_system_eval_comparison.csv
# Completed calibrated_system_eval in 3.7s
# Headline metrics: {"comparison_rows": [{"model": "lstm", "split": "test", "selected_calibrator": "gradient_boosting", "selection_rule": "best_val_mae_cp", "raw_MAE_CP": 6.800689655172413, "calibrated_MAE_CP": 6.544765840220386, "delta_MAE_CP": -0.2559238149520277, "raw_tolerance_hit_rate": 0.4531034482758621, "calibrated_tolerance_hit_rate": 0.3085399449035813, "delta_tolerance_hit_rate": -0.1445635033722808, "raw_coverage_rate": 0.9405986470206654, "calibrated_coverage_rate": 0.9496992133271632, "delta_coverage_rate": 0.0091005663064979, "raw_sharpness": 1.7204660885424783, "calibrated_sharpness": 2.2527623224
#
# Experiment completed. Stage status: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/reports/stage_status.json
# Report index: results/experiments/data_1to672_ctx96_h48/q50_q95_seed42/reports/report_index.json
