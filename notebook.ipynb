# %% [markdown]
# ## The Sketching Notebook, for current work ideas

# %%
from scripts.training_script import train_model

lstm_history = train_model(
    dataset_base="data_original",
    max_epochs=100,
    context_length=12,
    quantiles=(0.1, 0.5, 0.9),
)

# tensorboard --logdir ./results/logs
# Out:
# Epoch 1/100 - train_loss=4.793057 - train_rmse=16.253454 - val_loss=6.161536 - val_rmse=21.827801 - train_q0.1=1.494745 train_q0.5=5.612233 train_q0.9=7.273504 - val_q0.1=2.248686 val_q0.5=7.783555 val_q0.9=9.162256 - train_coverage=0.351034 train_interval_width=9.561157 - val_coverage=0.418605 val_interval_width=16.271484 - test_rmse=20.474344 - test_q0.1=2.116933 test_q0.5=7.306334 test_q0.9=8.372354 - test_coverage=0.406977 test_interval_width=16.271489 - best_val=6.161536 - patience=0/3
# Epoch 2/100 - train_loss=3.379184 - train_rmse=13.996780 - val_loss=5.318604 - val_rmse=21.365270 - train_q0.1=1.477136 train_q0.5=4.881069 train_q0.9=3.780962 - val_q0.1=2.255368 val_q0.5=7.582952 val_q0.9=6.457280 - train_coverage=0.650775 train_interval_width=20.123043 - val_coverage=0.593023 val_interval_width=23.482702 - test_rmse=20.043399 - test_q0.1=2.120814 test_q0.5=7.143889 test_q0.9=5.945473 - test_coverage=0.569767 test_interval_width=23.484173 - best_val=5.318604 - patience=0/3
# Epoch 3/100 - train_loss=2.914182 - train_rmse=13.288495 - val_loss=3.934914 - val_rmse=18.124917 - train_q0.1=1.412839 train_q0.5=4.345878 train_q0.9=2.984275 - val_q0.1=1.821269 val_q0.5=5.528450 val_q0.9=4.753621 - train_coverage=0.759432 train_interval_width=22.540956 - val_coverage=0.593023 val_interval_width=16.568093 - test_rmse=16.721035 - test_q0.1=1.707700 test_q0.5=4.876120 test_q0.9=4.365579 - test_coverage=0.686047 test_interval_width=16.636642 - best_val=3.934914 - patience=0/3
# Epoch 4/100 - train_loss=1.496612 - train_rmse=8.674078 - val_loss=2.642340 - val_rmse=13.234359 - train_q0.1=0.771817 train_q0.5=2.020144 train_q0.9=1.697760 - val_q0.1=1.264571 val_q0.5=3.390459 val_q0.9=3.215348 - train_coverage=0.721447 train_interval_width=8.560952 - val_coverage=0.569767 val_interval_width=9.793986 - test_rmse=11.908053 - test_q0.1=1.020502 test_q0.5=3.063117 test_q0.9=3.074563 - test_coverage=0.697674 test_interval_width=9.479229 - best_val=2.642340 - patience=0/3
# Epoch 5/100 - train_loss=1.140746 - train_rmse=6.842249 - val_loss=2.033091 - val_rmse=11.450488 - train_q0.1=0.592210 train_q0.5=1.557273 train_q0.9=1.271737 - val_q0.1=1.066235 val_q0.5=2.662534 val_q0.9=2.496768 - train_coverage=0.732558 train_interval_width=6.581330 - val_coverage=0.593023 val_interval_width=8.933302 - test_rmse=9.999941 - test_q0.1=0.831409 test_q0.5=2.264112 test_q0.9=2.241523 - test_coverage=0.709302 test_interval_width=8.405367 - best_val=2.033091 - patience=0/3
# Epoch 6/100 - train_loss=0.994864 - train_rmse=6.035396 - val_loss=1.765569 - val_rmse=10.409492 - train_q0.1=0.556135 train_q0.5=1.390103 train_q0.9=1.038989 - val_q0.1=0.991411 val_q0.5=2.370092 val_q0.9=2.070779 - train_coverage=0.760853 train_interval_width=6.565808 - val_coverage=0.639535 val_interval_width=8.644650 - test_rmse=8.912656 - test_q0.1=0.776035 test_q0.5=2.023001 test_q0.9=1.743424 - test_coverage=0.779070 test_interval_width=8.206506 - best_val=1.765569 - patience=0/3
# Epoch 7/100 - train_loss=0.919086 - train_rmse=5.528018 - val_loss=1.568348 - val_rmse=9.702949 - train_q0.1=0.534461 train_q0.5=1.295310 train_q0.9=0.927960 - val_q0.1=0.919994 val_q0.5=2.183727 val_q0.9=1.783890 - train_coverage=0.771447 train_interval_width=6.327980 - val_coverage=0.674419 val_interval_width=9.032285 - test_rmse=8.119929 - test_q0.1=0.693732 test_q0.5=1.780703 test_q0.9=1.594073 - test_coverage=0.813953 test_interval_width=8.536367 - best_val=1.568348 - patience=0/3
# Epoch 8/100 - train_loss=0.880711 - train_rmse=5.262270 - val_loss=1.466684 - val_rmse=9.343639 - train_q0.1=0.521360 train_q0.5=1.253082 train_q0.9=0.867817 - val_q0.1=0.899094 val_q0.5=2.135821 val_q0.9=1.567220 - train_coverage=0.778682 train_interval_width=6.458547 - val_coverage=0.651163 val_interval_width=8.717896 - test_rmse=7.659722 - test_q0.1=0.662111 test_q0.5=1.651070 test_q0.9=1.485496 - test_coverage=0.813953 test_interval_width=8.276452 - best_val=1.466684 - patience=0/3
# Epoch 9/100 - train_loss=0.854427 - train_rmse=5.057738 - val_loss=1.382148 - val_rmse=8.976353 - train_q0.1=0.516259 train_q0.5=1.221704 train_q0.9=0.825086 - val_q0.1=0.885734 val_q0.5=2.070221 val_q0.9=1.374560 - train_coverage=0.784625 train_interval_width=6.362692 - val_coverage=0.709302 val_interval_width=8.835769 - test_rmse=7.336958 - test_q0.1=0.685407 test_q0.5=1.596658 test_q0.9=1.368508 - test_coverage=0.802326 test_interval_width=8.441995 - best_val=1.382148 - patience=0/3
# Epoch 10/100 - train_loss=0.836086 - train_rmse=4.912218 - val_loss=1.292344 - val_rmse=8.595802 - train_q0.1=0.510869 train_q0.5=1.205391 train_q0.9=0.791981 - val_q0.1=0.874647 val_q0.5=1.914268 val_q0.9=1.259409 - train_coverage=0.793411 train_interval_width=6.501775 - val_coverage=0.755814 val_interval_width=8.664873 - test_rmse=7.075353 - test_q0.1=0.655393 test_q0.5=1.667522 test_q0.9=1.339532 - test_coverage=0.802326 test_interval_width=8.293322 - best_val=1.292344 - patience=0/3
# Epoch 11/100 - train_loss=0.815619 - train_rmse=4.773312 - val_loss=1.212884 - val_rmse=8.345663 - train_q0.1=0.506043 train_q0.5=1.183257 train_q0.9=0.757691 - val_q0.1=0.832840 val_q0.5=1.793034 val_q0.9=1.239066 - train_coverage=0.789276 train_interval_width=6.370397 - val_coverage=0.767442 val_interval_width=9.086140 - test_rmse=6.732351 - test_q0.1=0.637888 test_q0.5=1.546379 test_q0.9=1.264808 - test_coverage=0.848837 test_interval_width=8.546653 - best_val=1.212884 - patience=0/3
# Epoch 12/100 - train_loss=0.797791 - train_rmse=4.635986 - val_loss=1.235700 - val_rmse=8.174743 - train_q0.1=0.504738 train_q0.5=1.161810 train_q0.9=0.727246 - val_q0.1=0.848369 val_q0.5=1.786325 val_q0.9=1.237696 - train_coverage=0.788501 train_interval_width=6.397678 - val_coverage=0.779070 val_interval_width=9.285211 - test_rmse=6.503916 - test_q0.1=0.641919 test_q0.5=1.625613 test_q0.9=1.233165 - test_coverage=0.825581 test_interval_width=8.794171 - best_val=1.212884 - patience=1/3
# Epoch 13/100 - train_loss=0.789326 - train_rmse=4.543950 - val_loss=1.209369 - val_rmse=8.045194 - train_q0.1=0.507449 train_q0.5=1.154292 train_q0.9=0.706152 - val_q0.1=0.842924 val_q0.5=1.809104 val_q0.9=1.223238 - train_coverage=0.794186 train_interval_width=6.476783 - val_coverage=0.767442 val_interval_width=9.523200 - test_rmse=6.289774 - test_q0.1=0.635948 test_q0.5=1.622915 test_q0.9=1.208350 - test_coverage=0.790698 test_interval_width=8.979301 - best_val=1.209369 - patience=0/3
# Epoch 14/100 - train_loss=0.782120 - train_rmse=4.461270 - val_loss=1.165008 - val_rmse=7.757797 - train_q0.1=0.505666 train_q0.5=1.152952 train_q0.9=0.685962 - val_q0.1=0.829251 val_q0.5=1.708031 val_q0.9=1.192771 - train_coverage=0.796641 train_interval_width=6.515157 - val_coverage=0.720930 val_interval_width=9.086493 - test_rmse=5.899404 - test_q0.1=0.634091 test_q0.5=1.434005 test_q0.9=1.062798 - test_coverage=0.837209 test_interval_width=8.554033 - best_val=1.165008 - patience=0/3
# Epoch 15/100 - train_loss=0.764879 - train_rmse=4.320501 - val_loss=1.111901 - val_rmse=7.582422 - train_q0.1=0.500167 train_q0.5=1.123112 train_q0.9=0.671735 - val_q0.1=0.815328 val_q0.5=1.679155 val_q0.9=1.119678 - train_coverage=0.791602 train_interval_width=6.392025 - val_coverage=0.755814 val_interval_width=8.945660 - test_rmse=5.685023 - test_q0.1=0.622855 test_q0.5=1.399810 test_q0.9=1.045833 - test_coverage=0.802326 test_interval_width=8.432886 - best_val=1.111901 - patience=0/3
# Epoch 16/100 - train_loss=0.763872 - train_rmse=4.289399 - val_loss=1.113889 - val_rmse=7.426301 - train_q0.1=0.504411 train_q0.5=1.126815 train_q0.9=0.660192 - val_q0.1=0.800137 val_q0.5=1.697961 val_q0.9=1.103635 - train_coverage=0.796253 train_interval_width=6.415243 - val_coverage=0.779070 val_interval_width=9.206238 - test_rmse=5.519128 - test_q0.1=0.621030 test_q0.5=1.438841 test_q0.9=0.972462 - test_coverage=0.813953 test_interval_width=8.686827 - best_val=1.111901 - patience=1/3
# Epoch 17/100 - train_loss=0.752414 - train_rmse=4.213014 - val_loss=1.110754 - val_rmse=7.304452 - train_q0.1=0.499356 train_q0.5=1.112320 train_q0.9=0.645680 - val_q0.1=0.815495 val_q0.5=1.660261 val_q0.9=1.098037 - train_coverage=0.799483 train_interval_width=6.490710 - val_coverage=0.779070 val_interval_width=9.011737 - test_rmse=5.289558 - test_q0.1=0.606502 test_q0.5=1.344099 test_q0.9=0.957999 - test_coverage=0.825581 test_interval_width=8.465591 - best_val=1.110754 - patience=0/3
# Epoch 18/100 - train_loss=0.742979 - train_rmse=4.142807 - val_loss=1.110370 - val_rmse=7.205580 - train_q0.1=0.497463 train_q0.5=1.096169 train_q0.9=0.635480 - val_q0.1=0.784006 val_q0.5=1.651391 val_q0.9=1.123270 - train_coverage=0.800904 train_interval_width=6.441625 - val_coverage=0.790698 val_interval_width=9.349397 - test_rmse=5.186355 - test_q0.1=0.581786 test_q0.5=1.453581 test_q0.9=0.939041 - test_coverage=0.848837 test_interval_width=8.760348 - best_val=1.110370 - patience=0/3
# Epoch 19/100 - train_loss=0.739641 - train_rmse=4.087590 - val_loss=1.077195 - val_rmse=7.034960 - train_q0.1=0.496319 train_q0.5=1.096210 train_q0.9=0.626231 - val_q0.1=0.780290 val_q0.5=1.630819 val_q0.9=1.073920 - train_coverage=0.797674 train_interval_width=6.416449 - val_coverage=0.790698 val_interval_width=9.208152 - test_rmse=4.949662 - test_q0.1=0.591391 test_q0.5=1.364202 test_q0.9=0.881946 - test_coverage=0.837209 test_interval_width=8.630719 - best_val=1.077195 - patience=0/3
# Epoch 20/100 - train_loss=0.730815 - train_rmse=4.041570 - val_loss=1.148741 - val_rmse=7.189211 - train_q0.1=0.490612 train_q0.5=1.081374 train_q0.9=0.620401 - val_q0.1=0.772092 val_q0.5=1.739690 val_q0.9=1.175720 - train_coverage=0.799483 train_interval_width=6.180744 - val_coverage=0.744186 val_interval_width=9.193694 - test_rmse=4.950371 - test_q0.1=0.581382 test_q0.5=1.434003 test_q0.9=0.884920 - test_coverage=0.848837 test_interval_width=8.670591 - best_val=1.077195 - patience=1/3
# Epoch 21/100 - train_loss=0.728465 - train_rmse=4.010263 - val_loss=1.087423 - val_rmse=6.945972 - train_q0.1=0.489525 train_q0.5=1.076116 train_q0.9=0.619511 - val_q0.1=0.753458 val_q0.5=1.651153 val_q0.9=1.093041 - train_coverage=0.799612 train_interval_width=6.311353 - val_coverage=0.813953 val_interval_width=9.201299 - test_rmse=4.708962 - test_q0.1=0.561585 test_q0.5=1.393561 test_q0.9=0.841520 - test_coverage=0.848837 test_interval_width=8.728453 - best_val=1.077195 - patience=2/3
# Epoch 22/100 - train_loss=0.728019 - train_rmse=3.999427 - val_loss=1.053374 - val_rmse=6.778049 - train_q0.1=0.491111 train_q0.5=1.077400 train_q0.9=0.615191 - val_q0.1=0.781251 val_q0.5=1.602128 val_q0.9=1.036798 - train_coverage=0.792636 train_interval_width=6.293921 - val_coverage=0.779070 val_interval_width=8.958147 - test_rmse=4.517842 - test_q0.1=0.578400 test_q0.5=1.264323 test_q0.9=0.776682 - test_coverage=0.837209 test_interval_width=8.545459 - best_val=1.053374 - patience=0/3
# Epoch 23/100 - train_loss=0.723916 - train_rmse=3.978682 - val_loss=1.110462 - val_rmse=6.993850 - train_q0.1=0.491518 train_q0.5=1.075252 train_q0.9=0.604945 - val_q0.1=0.766509 val_q0.5=1.756598 val_q0.9=1.038037 - train_coverage=0.800646 train_interval_width=6.397327 - val_coverage=0.790698 val_interval_width=9.118691 - test_rmse=4.808443 - test_q0.1=0.584943 test_q0.5=1.469597 test_q0.9=0.752882 - test_coverage=0.802326 test_interval_width=8.552426 - best_val=1.053374 - patience=1/3
# Epoch 24/100 - train_loss=0.724669 - train_rmse=3.972359 - val_loss=1.063857 - val_rmse=6.708240 - train_q0.1=0.491062 train_q0.5=1.080687 train_q0.9=0.602175 - val_q0.1=0.777874 val_q0.5=1.602855 val_q0.9=1.025344 - train_coverage=0.801163 train_interval_width=6.398787 - val_coverage=0.767442 val_interval_width=9.101767 - test_rmse=4.504750 - test_q0.1=0.573927 test_q0.5=1.376954 test_q0.9=0.765757 - test_coverage=0.813953 test_interval_width=8.633800 - best_val=1.053374 - patience=2/3
# Early stopping at epoch 25: train_rmse=3.923198, val_rmse=6.726908, test_rmse=4.351651
# 'Final metrics'
#                   metric     value
# 0             train_loss  0.714958
# 1             train_rmse  3.923198
# 2               val_loss  1.074379
# 3               val_rmse  6.726908
# 4             train_q0.1  0.486787
# 5             train_q0.5  1.062899
# 6             train_q0.9  0.595085
# 7               val_q0.1  0.812385
# 8               val_q0.5  1.636727
# 9               val_q0.9  1.014243
# 10        train_coverage  0.799483
# 11          val_coverage  0.767442
# 12  train_interval_width  6.249758
# 13    val_interval_width  9.076004
# 14             test_loss  0.882317
# 15             test_rmse  4.351651
# 16             test_q0.1  0.578264
# 17             test_q0.5  1.321258
# 18             test_q0.9  0.732558
# 19         test_coverage  0.825581
# 20   test_interval_width  8.734657
# 21              best_val  1.053374
# 22              patience       3/3

# %%
# Chronos-2 quantile evaluation on the input dataset
# !python3 scripts/chronos2_eval.py --data-path data/datasets/data_original_train.csv \
    --context-length 12 --quantiles 0.1,0.5,0.9
# Out:
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Chronos-2 metrics
#             metric     value
# 0             rmse  3.904853
# 1  median_quantile  0.500000
# 2         coverage  0.788114
# 3   interval_width  7.114337
# 4   interval_lower  0.100000
# 5   interval_upper  0.900000
# 6     pinball_q0.1  0.501699
# 7     pinball_q0.5  1.081675
# 8     pinball_q0.9  0.570550
# Saved results to results/evals/chronos2_test_rmse.json

# %%
# Chronos-2 quantile evaluation on the input dataset
# !python3 scripts/chronos2_eval.py --data-path data/datasets/data_original_val.csv \
    --context-length 12 --quantiles 0.1,0.5,0.9
# Out:
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Chronos-2 metrics
#             metric      value
# 0             rmse   3.296815
# 1  median_quantile   0.500000
# 2         coverage   0.883721
# 3   interval_width  11.812506
# 4   interval_lower   0.100000
# 5   interval_upper   0.900000
# 6     pinball_q0.1   0.582776
# 7     pinball_q0.5   1.173555
# 8     pinball_q0.9   0.701007
# Saved results to results/chronos_eval_benchmarking/evals/chronos2_eval.json

# %%
# Chronos-2 quantile evaluation on the input dataset
# !python3 scripts/chronos2_eval.py --data-path data/datasets/data_original_test.csv \
    --context-length 12 --quantiles 0.1,0.5,0.9
# Out:
# /Users/colinminini/Desktop/SCOC_ICE/LLM6G-Repository/.venv/lib/python3.13/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Chronos-2 metrics
#             metric     value
# 0             rmse  2.949635
# 1  median_quantile  0.500000
# 2         coverage  0.895349
# 3   interval_width  8.807986
# 4   interval_lower  0.100000
# 5   interval_upper  0.900000
# 6     pinball_q0.1  0.436435
# 7     pinball_q0.5  1.053503
# 8     pinball_q0.9  0.541610
# Saved results to results/chronos_eval_benchmarking/evals/chronos2_eval.json
